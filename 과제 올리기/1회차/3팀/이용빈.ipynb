# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = [[2, 81], [4, 93], [6, 91], [8, 97]]
x = [i[0] for i in data]
y = [i[1] for i in data]

x_data = np.array(x)
y_data = np.array(y)

a = 0.
b = 0.

lr = 0.03

epochs = 2001

for i in range(epochs):
  y_pred = a * x_data + b
  error = y_data - y_pred

  a_diff = -(2/len(x_data)) * sum(x_data * (error)) # error = (a * x + b - y_pred) '-'를 앞으로 뺌
  b_diff = -(2/len(x_data)) * sum(error)

  a = a - lr * a_diff
  b = b - lr * b_diff

  if i % 100 == 0:
    print('epochs = %d, a = %f, b = %f' %(i, a, b))
# Out:
# epochs = 0, a = 27.840000, b = 5.430000
# epochs = 100, a = 7.073858, b = 50.511662
# epochs = 200, a = 4.095999, b = 68.282244
# epochs = 300, a = 2.975683, b = 74.967813
# epochs = 400, a = 2.554202, b = 77.483029
# epochs = 500, a = 2.395635, b = 78.429292
# epochs = 600, a = 2.335979, b = 78.785291
# epochs = 700, a = 2.313536, b = 78.919223
# epochs = 800, a = 2.305092, b = 78.969610
# epochs = 900, a = 2.301916, b = 78.988567
# epochs = 1000, a = 2.300721, b = 78.995699
# epochs = 1100, a = 2.300271, b = 78.998382
# epochs = 1200, a = 2.300102, b = 78.999391
# epochs = 1300, a = 2.300038, b = 78.999771
# epochs = 1400, a = 2.300014, b = 78.999914
# epochs = 1500, a = 2.300005, b = 78.999968
# epochs = 1600, a = 2.300002, b = 78.999988
# epochs = 1700, a = 2.300001, b = 78.999995
# epochs = 1800, a = 2.300000, b = 78.999998
# epochs = 1900, a = 2.300000, b = 78.999999
# epochs = 2000, a = 2.300000, b = 79.000000

# %%
plt.scatter(x_data, y_data)
plt.plot(x_data, y_pred)
plt.show()

# %%
data = [[2, 0, 81], [4, 4, 93], [6, 2, 91], [8, 3, 97]]
x1 = [i[0] for i in data]
x2 = [i[1] for i in data]
y = [i[2] for i in data]

x1_data = np.array(x1)
x2_data = np.array(x2)
y_data = np.array(y)

a1 = 0.
a2 = 0.
b = 0.

lr = 0.02

epochs = 2001

for i in range(epochs):
  y_pred = a1 * x1_data + a2 * x2_data + b
  error = y_data - y_pred

  a1_diff = -(2/len(x1_data)) * sum(x1_data * (error))
  a2_diff = -(2/len(x1_data)) * sum(x2_data * (error))
  b_diff = -(2/len(x1_data)) * sum(error)

  a1 = a1 - lr * a1_diff
  a2 = a2 - lr * a2_diff
  b = b - lr * b_diff

  if i % 100 == 0:
    print('epochs = %d, a1 = %f, a2 = %f, b = %f' %(i, a1, a2, b))
# Out:
# epochs = 0, a1 = 18.560000, a2 = 8.450000, b = 3.620000
# epochs = 100, a1 = 7.299356, a2 = 4.286665, b = 38.042653
# epochs = 200, a1 = 4.568312, a2 = 3.345127, b = 56.790141
# epochs = 300, a1 = 3.123531, a2 = 2.846283, b = 66.709986
# epochs = 400, a1 = 2.359057, a2 = 2.582327, b = 71.958862
# epochs = 500, a1 = 1.954552, a2 = 2.442661, b = 74.736193
# epochs = 600, a1 = 1.740516, a2 = 2.368759, b = 76.205758
# epochs = 700, a1 = 1.627264, a2 = 2.329656, b = 76.983348
# epochs = 800, a1 = 1.567339, a2 = 2.308965, b = 77.394793
# epochs = 900, a1 = 1.535631, a2 = 2.298017, b = 77.612500
# epochs = 1000, a1 = 1.518853, a2 = 2.292224, b = 77.727695
# epochs = 1100, a1 = 1.509976, a2 = 2.289159, b = 77.788648
# epochs = 1200, a1 = 1.505279, a2 = 2.287537, b = 77.820901
# epochs = 1300, a1 = 1.502793, a2 = 2.286679, b = 77.837966
# epochs = 1400, a1 = 1.501478, a2 = 2.286225, b = 77.846996
# epochs = 1500, a1 = 1.500782, a2 = 2.285984, b = 77.851774
# ...

# %%
from mpl_toolkits.mplot3d import axes3d # matplotlib 3.2.0 이후 projection=3d에서 필요하지 않음
ax = plt.axes(projection='3d')
ax.set_xlabel('study_hour')
ax.set_ylabel('private_class')
ax.set_zlabel('Score')
ax.dist = 11
ax.scatter(x1_data, x2_data, y_data, cmap='inferno')
#ax.plot_wireframe(x1_data, x2_data, y_data, cmap='inferno')

plt.show()
